# %%
import tensorflow as tf
# Out:
# C:\Users\g2arc\Anaconda3\envs\python3.7\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\g2arc\Anaconda3\envs\python3.7\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\g2arc\Anaconda3\envs\python3.7\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\g2arc\Anaconda3\envs\python3.7\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\g2arc\Anaconda3\envs\python3.7\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\g2arc\Anaconda3\envs\python3.7\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\g2arc\Anaconda3\envs\python3.7\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\g2arc\Anaconda3\envs\python3.7\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\g2arc\Anaconda3\envs\python3.7\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\g2arc\Anaconda3\envs\python3.7\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\g2arc\Anaconda3\envs\python3.7\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\g2arc\Anaconda3\envs\python3.7\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
from networks.UNet3D import UNet3D

# %%
model = UNet3D('dropblock', [0.1, 3])
model.compile(optimizer='adam',
              loss=tf.keras.losses.MeanSquaredError(),
              metrics=['accuracy'])
model.build(input_shape=(1, 128, 128, 20))
model.summary()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0816 09:36:26.846729 20756 deprecation.py:506] From C:\Users\g2arc\Anaconda3\envs\python3.7\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Model: "u_net3d"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# DropBlock_0 (DropBlock3D)    multiple                  0
# _________________________________________________________________
# DropBlock_1 (DropBlock3D)    multiple                  0
# _________________________________________________________________
# DropBlock_2 (DropBlock3D)    multiple                  0
# _________________________________________________________________
# DropBlock_3 (DropBlock3D)    multiple                  0
# _________________________________________________________________
# DropBlock_4 (DropBlock3D)    multiple                  0
# _________________________________________________________________
# DropBlock_5 (DropBlock3D)    multiple                  0
# _________________________________________________________________
# DropBlock_6 (DropBlock3D)    multiple                  0
# _________________________________________________________________
# DropBlock_7 (DropBlock3D)    multiple                  0
# _________________________________________________________________
# DropBlock_8 (DropBlock3D)    multiple                  0
# _________________________________________________________________
# DropBlock_9 (DropBlock3D)    multiple                  0
# _________________________________________________________________
# DropBlock_10 (DropBlock3D)   multiple                  0
# _________________________________________________________________
# DropBlock_11 (DropBlock3D)   multiple                  0
# _________________________________________________________________
# DropBlock_12 (DropBlock3D)   multiple                  0
# _________________________________________________________________
# DropBlock_13 (DropBlock3D)   multiple                  0
# _________________________________________________________________
# DropBlock_14 (DropBlock3D)   multiple                  0
# _________________________________________________________________
# DropBlock_15 (DropBlock3D)   multiple                  0
# _________________________________________________________________
# DropBlock_16 (DropBlock3D)   multiple                  0
# _________________________________________________________________
# DropBlock_17 (DropBlock3D)   multiple                  0
# _________________________________________________________________
# DropBlock_18 (DropBlock3D)   multiple                  0
# _________________________________________________________________
# DropBlock_19 (DropBlock3D)   multiple                  0
# _________________________________________________________________
# DropBlock_20 (DropBlock3D)   multiple                  0
# _________________________________________________________________
# DropBlock_21 (DropBlock3D)   multiple                  0
# _________________________________________________________________
# DropBlock_22 (DropBlock3D)   multiple                  0
# _________________________________________________________________
# conv3d_32_1 (Conv3D)         multiple                  896
# _________________________________________________________________
# conv3d_32_2 (Conv3D)         multiple                  27680
# _________________________________________________________________
# maxpool_3d_1 (MaxPooling3D)  multiple                  0
# _________________________________________________________________
# conv3d_64_1 (Conv3D)         multiple                  55360
# _________________________________________________________________
# conv3d_64_2 (Conv3D)         multiple                  110656
# _________________________________________________________________
# maxpool_3d_2 (MaxPooling3D)  multiple                  0
# _________________________________________________________________
# conv3d_128_1 (Conv3D)        multiple                  221312
# _________________________________________________________________
# conv3d_128_2 (Conv3D)        multiple                  442496
# _________________________________________________________________
# maxpool_3d_3 (MaxPooling3D)  multiple                  0
# _________________________________________________________________
# conv3d_256_1 (Conv3D)        multiple                  884992
# _________________________________________________________________
# conv3d_256_2 (Conv3D)        multiple                  1769728
# _________________________________________________________________
# maxpool_3d_4 (MaxPooling3D)  multiple                  0
# _________________________________________________________________
# conv3d_512_1 (Conv3D)        multiple                  3539456
# _________________________________________________________________
# conv3d_512_2 (Conv3D)        multiple                  7078400
# _________________________________________________________________
# conv3d_trans_256_1 (Conv3DTr multiple                  3539200
# _________________________________________________________________
# concat_256_1 (Concatenate)   multiple                  0
# _________________________________________________________________
# conv3d_256_3 (Conv3D)        multiple                  3539200
# _________________________________________________________________
# conv3d_256_4 (Conv3D)        multiple                  1769728
# _________________________________________________________________
# conv3d_trans_128_1 (Conv3DTr multiple                  884864
# _________________________________________________________________
# concat_128_1 (Concatenate)   multiple                  0
# _________________________________________________________________
# conv3d_128_3 (Conv3D)        multiple                  884864
# _________________________________________________________________
# conv3d_128_4 (Conv3D)        multiple                  442496
# _________________________________________________________________
# conv3d_trans_64_1 (Conv3DTra multiple                  221248
# _________________________________________________________________
# concat_64_1 (Concatenate)    multiple                  0
# _________________________________________________________________
# conv3d_64_3 (Conv3D)         multiple                  221248
# _________________________________________________________________
# conv3d_64_4 (Conv3D)         multiple                  110656
# _________________________________________________________________
# conv3d_trans_32_1 (Conv3DTra multiple                  55328
# _________________________________________________________________
# concat_32_1 (Concatenate)    multiple                  0
# _________________________________________________________________
# conv3d_32_3 (Conv3D)         multiple                  55328
# _________________________________________________________________
# conv3d_32_4 (Conv3D)         multiple                  27680
# _________________________________________________________________
# conv3d_1_1 (Conv3D)          multiple                  865
# =================================================================
# Total params: 25,883,681
# Trainable params: 25,883,681
# Non-trainable params: 0
# _________________________________________________________________

# %%
from networks.UNet2D1D import UNet2D1D

# %%
model = UNet2D1D()
model.compile(optimizer='adam',
              loss=tf.keras.losses.MeanSquaredError(),
              metrics=['accuracy'])
model.build(input_shape=(None, 128, 128, 20))
model.summary()
# Out:
# Model: "u_net2d1d"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_1_1 (Conv3D)          multiple                  865
# _________________________________________________________________
# l_Permute_32_1 (Permute)     multiple                  0
# _________________________________________________________________
# l_Conv2D_32 (Conv2D)         multiple                  320
# _________________________________________________________________
# l_Permute_32_2 (Permute)     multiple                  0
# _________________________________________________________________
# l_Conv1D_32 (Conv1D)         multiple                  3104
# _________________________________________________________________
# l_MaxPool3D_32 (MaxPooling3D multiple                  0
# _________________________________________________________________
# l_Permute_64_1 (Permute)     multiple                  0
# _________________________________________________________________
# l_Conv2D_64 (Conv2D)         multiple                  18496
# _________________________________________________________________
# l_Permute_64_2 (Permute)     multiple                  0
# _________________________________________________________________
# l_Conv1D_64 (Conv1D)         multiple                  12352
# _________________________________________________________________
# l_MaxPool3D_64 (MaxPooling3D multiple                  0
# _________________________________________________________________
# l_Permute_128_1 (Permute)    multiple                  0
# _________________________________________________________________
# l_Conv2D_128 (Conv2D)        multiple                  73856
# _________________________________________________________________
# l_Permute_128_2 (Permute)    multiple                  0
# _________________________________________________________________
# l_Conv1D_128 (Conv1D)        multiple                  49280
# _________________________________________________________________
# l_MaxPool3D_128 (MaxPooling3 multiple                  0
# _________________________________________________________________
# l_Permute_256_1 (Permute)    multiple                  0
# _________________________________________________________________
# l_Conv2D_256 (Conv2D)        multiple                  295168
# _________________________________________________________________
# l_Permute_256_2 (Permute)    multiple                  0
# _________________________________________________________________
# l_Conv1D_256 (Conv1D)        multiple                  196864
# _________________________________________________________________
# l_MaxPool3D_256 (MaxPooling3 multiple                  0
# _________________________________________________________________
# l_Permute_512_1 (Permute)    multiple                  0
# _________________________________________________________________
# l_Conv2D_512 (Conv2D)        multiple                  1180160
# _________________________________________________________________
# l_Permute_512_2 (Permute)    multiple                  0
# _________________________________________________________________
# l_Conv1D_512 (Conv1D)        multiple                  786944
# _________________________________________________________________
# r_UpConv3D_256 (Conv3DTransp multiple                  1048832
# _________________________________________________________________
# r_Permute_256_1 (Permute)    multiple                  0
# _________________________________________________________________
# r_Conv2D_256 (Conv2D)        multiple                  1179904
# _________________________________________________________________
# r_Permute_256_2 (Permute)    multiple                  0
# _________________________________________________________________
# r_Conv1D_256 (Conv1D)        multiple                  196864
# _________________________________________________________________
# r_UpConv3D_128 (Conv3DTransp multiple                  262272
# _________________________________________________________________
# r_Permute_128_1 (Permute)    multiple                  0
# _________________________________________________________________
# r_Conv2D_128 (Conv2D)        multiple                  295040
# _________________________________________________________________
# r_Permute_128_2 (Permute)    multiple                  0
# _________________________________________________________________
# r_Conv1D_128 (Conv1D)        multiple                  49280
# _________________________________________________________________
# r_UpConv3D_64 (Conv3DTranspo multiple                  65600
# _________________________________________________________________
# r_Permute_64_1 (Permute)     multiple                  0
# _________________________________________________________________
# r_Conv2D_64 (Conv2D)         multiple                  73792
# _________________________________________________________________
# r_Permute_64_2 (Permute)     multiple                  0
# _________________________________________________________________
# r_Conv1D_64 (Conv1D)         multiple                  12352
# _________________________________________________________________
# r_UpConv3D_32 (Conv3DTranspo multiple                  16416
# _________________________________________________________________
# r_Permute_32_1 (Permute)     multiple                  0
# _________________________________________________________________
# r_Conv2D_32 (Conv2D)         multiple                  18464
# _________________________________________________________________
# r_Permute_32_2 (Permute)     multiple                  0
# _________________________________________________________________
# r_Conv1D_32 (Conv1D)         multiple                  3104
# =================================================================
# Total params: 5,839,329
# Trainable params: 5,839,329
# Non-trainable params: 0
# _________________________________________________________________

# %%
from networks.UNet3D_2 import UNet3D_2

# %%
model = UNet3D_2('dropblock', [0.9, 3])
model.compile(optimizer='adam',
              loss=tf.keras.losses.MeanSquaredError(),
              metrics=['accuracy'])
model.build(input_shape=(None, 128, 128, 20))
model.summary()
# Out:
# Model: "u_net3d_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_1_1 (Conv3D)          multiple                  865
# _________________________________________________________________
# l_Conv3D_32_1 (Conv3D)       multiple                  896
# _________________________________________________________________
# DropBlock_l_Conv3D_32_1 (Dro multiple                  0
# _________________________________________________________________
# l_Conv3D_32_2 (Conv3D)       multiple                  27680
# _________________________________________________________________
# DropBlock_l_Conv3D_32_2 (Dro multiple                  0
# _________________________________________________________________
# l_MaxPool3D_32 (MaxPooling3D multiple                  0
# _________________________________________________________________
# l_Conv3D_64_1 (Conv3D)       multiple                  55360
# _________________________________________________________________
# DropBlock_l_Conv3D_64_1 (Dro multiple                  0
# _________________________________________________________________
# l_Conv3D_64_2 (Conv3D)       multiple                  110656
# _________________________________________________________________
# DropBlock_l_Conv3D_64_2 (Dro multiple                  0
# _________________________________________________________________
# l_MaxPool3D_64 (MaxPooling3D multiple                  0
# _________________________________________________________________
# l_Conv3D_128_1 (Conv3D)      multiple                  221312
# _________________________________________________________________
# DropBlock_l_Conv3D_128_1 (Dr multiple                  0
# _________________________________________________________________
# l_Conv3D_128_2 (Conv3D)      multiple                  442496
# _________________________________________________________________
# DropBlock_l_Conv3D_128_2 (Dr multiple                  0
# _________________________________________________________________
# l_MaxPool3D_128 (MaxPooling3 multiple                  0
# _________________________________________________________________
# l_Conv3D_256_1 (Conv3D)      multiple                  884992
# _________________________________________________________________
# DropBlock_l_Conv3D_256_1 (Dr multiple                  0
# _________________________________________________________________
# l_Conv3D_256_2 (Conv3D)      multiple                  1769728
# _________________________________________________________________
# DropBlock_l_Conv3D_256_2 (Dr multiple                  0
# _________________________________________________________________
# l_MaxPool3D_256 (MaxPooling3 multiple                  0
# _________________________________________________________________
# l_Conv3D_512_1 (Conv3D)      multiple                  3539456
# _________________________________________________________________
# DropBlock_l_Conv3D_512_1 (Dr multiple                  0
# _________________________________________________________________
# l_Conv3D_512_2 (Conv3D)      multiple                  7078400
# _________________________________________________________________
# DropBlock_l_Conv3D_512_2 (Dr multiple                  0
# _________________________________________________________________
# r_UpConv3D_256 (Conv3DTransp multiple                  1048832
# _________________________________________________________________
# DropBlock_r_UpConv3D_256 (Dr multiple                  0
# _________________________________________________________________
# r_Conv3D_256_1 (Conv3D)      multiple                  3539200
# _________________________________________________________________
# DropBlock_r_Conv3D_256_1 (Dr multiple                  0
# _________________________________________________________________
# r_Conv3D_256_2 (Conv3D)      multiple                  1769728
# _________________________________________________________________
# DropBlock_r_Conv3D_256_2 (Dr multiple                  0
# _________________________________________________________________
# r_UpConv3D_128 (Conv3DTransp multiple                  262272
# _________________________________________________________________
# DropBlock_r_UpConv3D_128 (Dr multiple                  0
# _________________________________________________________________
# r_Conv3D_128_1 (Conv3D)      multiple                  884864
# _________________________________________________________________
# DropBlock_r_Conv3D_128_1 (Dr multiple                  0
# _________________________________________________________________
# r_Conv3D_128_2 (Conv3D)      multiple                  442496
# _________________________________________________________________
# DropBlock_r_Conv3D_128_2 (Dr multiple                  0
# _________________________________________________________________
# r_UpConv3D_64 (Conv3DTranspo multiple                  65600
# _________________________________________________________________
# DropBlock_r_UpConv3D_64 (Dro multiple                  0
# _________________________________________________________________
# r_Conv3D_64_1 (Conv3D)       multiple                  221248
# _________________________________________________________________
# DropBlock_r_Conv3D_64_1 (Dro multiple                  0
# _________________________________________________________________
# r_Conv3D_64_2 (Conv3D)       multiple                  110656
# _________________________________________________________________
# DropBlock_r_Conv3D_64_2 (Dro multiple                  0
# _________________________________________________________________
# r_UpConv3D_32 (Conv3DTranspo multiple                  16416
# _________________________________________________________________
# DropBlock_r_UpConv3D_32 (Dro multiple                  0
# _________________________________________________________________
# r_Conv3D_32_1 (Conv3D)       multiple                  55328
# _________________________________________________________________
# DropBlock_r_Conv3D_32_1 (Dro multiple                  0
# _________________________________________________________________
# r_Conv3D_32_2 (Conv3D)       multiple                  27680
# _________________________________________________________________
# DropBlock_r_Conv3D_32_2 (Dro multiple                  0
# _________________________________________________________________
# DropBlock_conv3d_1_1 (DropBl multiple                  0
# =================================================================
# Total params: 22,576,161
# Trainable params: 22,576,161
# Non-trainable params: 0
# _________________________________________________________________

# %%
from networks.UNet2D2D import UNet2D2D

# %%
model = UNet2D2D('batch_norm', [0.3])
model.compile(optimizer='adam',
              loss=tf.keras.losses.MeanSquaredError(),
              metrics=['accuracy'])
model.build(input_shape=(None, 128, 128, 20))
model.summary()
# Out:
# Model: "u_net2d2d"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_1_1 (Conv3D)          multiple                  865
# _________________________________________________________________
# l_Permute_32_1 (Permute)     multiple                  0
# _________________________________________________________________
# l_Conv2D_32_1 (Conv2D)       multiple                  320
# _________________________________________________________________
# Batch_Norm_l_Conv2D_32_1 (Ba multiple                  128
# _________________________________________________________________
# l_Permute_32_2 (Permute)     multiple                  0
# _________________________________________________________________
# l_Conv2D_32_2 (Conv2D)       multiple                  9248
# _________________________________________________________________
# Batch_Norm_l_Conv2D_32_2 (Ba multiple                  128
# _________________________________________________________________
# l_MaxPool3D_32 (MaxPooling3D multiple                  0
# _________________________________________________________________
# l_Permute_64_1 (Permute)     multiple                  0
# _________________________________________________________________
# l_Conv2D_64_1 (Conv2D)       multiple                  18496
# _________________________________________________________________
# Batch_Norm_l_Conv2D_64_1 (Ba multiple                  256
# _________________________________________________________________
# l_Permute_64_2 (Permute)     multiple                  0
# _________________________________________________________________
# l_Conv2D_64_2 (Conv2D)       multiple                  36928
# _________________________________________________________________
# Batch_Norm_l_Conv2D_64_2 (Ba multiple                  256
# _________________________________________________________________
# l_MaxPool3D_64 (MaxPooling3D multiple                  0
# _________________________________________________________________
# l_Permute_128_1 (Permute)    multiple                  0
# _________________________________________________________________
# l_Conv2D_128_1 (Conv2D)      multiple                  73856
# _________________________________________________________________
# Batch_Norm_l_Conv2D_128_1 (B multiple                  512
# _________________________________________________________________
# l_Permute_128_2 (Permute)    multiple                  0
# _________________________________________________________________
# l_Conv2D_128_2 (Conv2D)      multiple                  147584
# _________________________________________________________________
# Batch_Norm_l_Conv2D_128_2 (B multiple                  512
# _________________________________________________________________
# l_MaxPool3D_128 (MaxPooling3 multiple                  0
# _________________________________________________________________
# l_Permute_256_1 (Permute)    multiple                  0
# _________________________________________________________________
# l_Conv2D_256_1 (Conv2D)      multiple                  295168
# _________________________________________________________________
# Batch_Norm_l_Conv2D_256_1 (B multiple                  1024
# _________________________________________________________________
# l_Permute_256_2 (Permute)    multiple                  0
# _________________________________________________________________
# l_Conv2D_256_2 (Conv2D)      multiple                  590080
# _________________________________________________________________
# Batch_Norm_l_Conv2D_256_2 (B multiple                  1024
# _________________________________________________________________
# l_MaxPool3D_256 (MaxPooling3 multiple                  0
# _________________________________________________________________
# l_Permute_512_1 (Permute)    multiple                  0
# _________________________________________________________________
# l_Conv2D_512_1 (Conv2D)      multiple                  1180160
# _________________________________________________________________
# Batch_Norm_l_Conv2D_512_1 (B multiple                  2048
# _________________________________________________________________
# l_Permute_512_2 (Permute)    multiple                  0
# _________________________________________________________________
# l_Conv2D_512_2 (Conv2D)      multiple                  2359808
# _________________________________________________________________
# Batch_Norm_l_Conv2D_512_2 (B multiple                  2048
# _________________________________________________________________
# r_UpConv3D_256 (Conv3DTransp multiple                  1048832
# _________________________________________________________________
# Batch_Norm_r_UpConv3D_256 (B multiple                  1024
# _________________________________________________________________
# r_Permute_256_1 (Permute)    multiple                  0
# _________________________________________________________________
# r_Conv2D_256_1 (Conv2D)      multiple                  1179904
# _________________________________________________________________
# Batch_Norm_r_Conv2D_256_1 (B multiple                  1024
# _________________________________________________________________
# r_Permute_256_2 (Permute)    multiple                  0
# _________________________________________________________________
# r_Conv2D_256_2 (Conv2D)      multiple                  590080
# _________________________________________________________________
# Batch_Norm_r_Conv2D_256_2 (B multiple                  1024
# _________________________________________________________________
# r_UpConv3D_128 (Conv3DTransp multiple                  262272
# _________________________________________________________________
# Batch_Norm_r_UpConv3D_128 (B multiple                  512
# _________________________________________________________________
# r_Permute_128_1 (Permute)    multiple                  0
# _________________________________________________________________
# r_Conv2D_128_1 (Conv2D)      multiple                  295040
# _________________________________________________________________
# Batch_Norm_r_Conv2D_128_1 (B multiple                  512
# _________________________________________________________________
# r_Permute_128_2 (Permute)    multiple                  0
# _________________________________________________________________
# r_Conv2D_128_2 (Conv2D)      multiple                  147584
# _________________________________________________________________
# Batch_Norm_r_Conv2D_128_2 (B multiple                  512
# _________________________________________________________________
# r_UpConv3D_64 (Conv3DTranspo multiple                  65600
# _________________________________________________________________
# Batch_Norm_r_UpConv3D_64 (Ba multiple                  256
# _________________________________________________________________
# r_Permute_64_1 (Permute)     multiple                  0
# _________________________________________________________________
# r_Conv2D_64_1 (Conv2D)       multiple                  73792
# _________________________________________________________________
# Batch_Norm_r_Conv2D_64_1 (Ba multiple                  256
# _________________________________________________________________
# r_Permute_64_2 (Permute)     multiple                  0
# _________________________________________________________________
# r_Conv2D_64_2 (Conv2D)       multiple                  36928
# _________________________________________________________________
# Batch_Norm_r_Conv2D_64_2 (Ba multiple                  256
# _________________________________________________________________
# r_UpConv3D_32 (Conv3DTranspo multiple                  16416
# _________________________________________________________________
# Batch_Norm_r_UpConv3D_32 (Ba multiple                  128
# _________________________________________________________________
# r_Permute_32_1 (Permute)     multiple                  0
# _________________________________________________________________
# r_Conv2D_32_1 (Conv2D)       multiple                  18464
# _________________________________________________________________
# Batch_Norm_r_Conv2D_32_1 (Ba multiple                  128
# _________________________________________________________________
# r_Permute_32_2 (Permute)     multiple                  0
# _________________________________________________________________
# r_Conv2D_32_2 (Conv2D)       multiple                  9248
# _________________________________________________________________
# Batch_Norm_r_Conv2D_32_2 (Ba multiple                  128
# _________________________________________________________________
# Batch_Norm_conv3d_1_1 (Batch multiple                  4
# =================================================================
# Total params: 8,470,373
# Trainable params: 8,463,523
# Non-trainable params: 6,850
# _________________________________________________________________
