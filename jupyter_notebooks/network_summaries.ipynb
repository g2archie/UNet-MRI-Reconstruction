# %%
import tensorflow as tf

# %%
from networks.UNet3D import UNet3D

# %%
model = UNet3D()
model.compile(optimizer='adam',
              loss=tf.keras.losses.MeanSquaredError(),
              metrics=['accuracy'])
model.build(input_shape=(None, 128, 128, 20))
model.summary()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0827 03:27:45.305688 139994107139840 deprecation.py:506] From /home/wentao/anaconda3/envs/python3.7/lib/python3.7/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Model: "u_net3d"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv3d_1_1 (Conv3D)          multiple                  865
# _________________________________________________________________
# l_Conv3D_32_1 (Conv3D)       multiple                  896
# _________________________________________________________________
# l_Conv3D_32_2 (Conv3D)       multiple                  27680
# ...

# %%
from networks.UNet2D1D import UNet2D1D

# %%
model = UNet2D1D()
model.compile(optimizer='adam',
              loss=tf.keras.losses.MeanSquaredError(),
              metrics=['accuracy'])
model.build(input_shape=(None, 128, 128, 20))
model.summary()
# Out:
# Model: "u_net2d1d"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv3d_1_1 (Conv3D)          multiple                  865
# _________________________________________________________________
# l_Permute_32_1 (Permute)     multiple                  0
# _________________________________________________________________
# l_Conv2D_32 (Conv2D)         multiple                  320
# _________________________________________________________________
# l_Permute_32_2 (Permute)     multiple                  0
# _________________________________________________________________
# l_Conv1D_32 (Conv1D)         multiple                  3104
# _________________________________________________________________
# l_MaxPool3D_32 (MaxPooling3D multiple                  0
# _________________________________________________________________
# l_Permute_64_1 (Permute)     multiple                  0
# ...

# %%
from networks.UNet3D_old import UNet3D_old

# %%
model = UNet3D_old()
model.compile(optimizer='adam',
              loss=tf.keras.losses.MeanSquaredError(),
              metrics=['accuracy'])
model.build(input_shape=(None, 128, 128, 20))
model.summary()
# Out:
# Model: "u_net3d_old"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv3d_32_1 (Conv3D)         multiple                  896
# _________________________________________________________________
# conv3d_32_2 (Conv3D)         multiple                  27680
# _________________________________________________________________
# maxpool_3d_1 (MaxPooling3D)  multiple                  0
# _________________________________________________________________
# conv3d_64_1 (Conv3D)         multiple                  55360
# _________________________________________________________________
# conv3d_64_2 (Conv3D)         multiple                  110656
# _________________________________________________________________
# maxpool_3d_2 (MaxPooling3D)  multiple                  0
# _________________________________________________________________
# conv3d_128_1 (Conv3D)        multiple                  221312
# ...

# %%
from networks.UNet2D2D import UNet2D2D

# %%
model = UNet2D2D()
model.compile(optimizer='adam',
              loss=tf.keras.losses.MeanSquaredError(),
              metrics=['accuracy'])
model.build(input_shape=(None, 128, 128, 20))
model.summary()
# Out:
# Model: "u_net2d2d"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv3d_1_1 (Conv3D)          multiple                  865
# _________________________________________________________________
# l_Permute_32_1 (Permute)     multiple                  0
# _________________________________________________________________
# l_Conv2D_32_1 (Conv2D)       multiple                  320
# _________________________________________________________________
# l_Permute_32_2 (Permute)     multiple                  0
# _________________________________________________________________
# l_Conv2D_32_2 (Conv2D)       multiple                  9248
# _________________________________________________________________
# l_MaxPool3D_32 (MaxPooling3D multiple                  0
# _________________________________________________________________
# l_Permute_64_1 (Permute)     multiple                  0
# ...
